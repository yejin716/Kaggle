# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
path = '../../../data/insurance.csv'

insurance_data = pd.read_csv(path)
insurance_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
#scatter plot 
# 두개의 변수간의 관계를 나타냄 (산점도)

sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
#regplot >> 추세선 넣기 

sns.regplot(x=insurance_data['bmi'], y=insurance_data['charges'])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
# 어떤 조건에 해당되는 값 표시 
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'], hue=insurance_data['smoker'])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
#lmplot >> 회귀선과 플롯을 동시에 그리기
sns.lmplot(x='bmi', y='charges', hue='smoker', data=insurance_data)

# %%
#swarmplot >>  데이터를 나타내는 점이 겹치지 않도록 옆으로 이동
# 카테고리값에 따른 각 분포의 실제 데이터나 전체 형상을 보여준다

sns.swarmplot(x = insurance_data['smoker'], y= insurance_data['charges'])

# 흡연할때가 흡연을 안하는 것보다 보험비가 더 높음
# Out:
# d:\Anaconda\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 37.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='smoker', ylabel='charges'>
# d:\Anaconda\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 60.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
